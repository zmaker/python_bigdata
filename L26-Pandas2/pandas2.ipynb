# %% [markdown]
# ## Pandas - Indici

# %% [markdown]
# come funzionano gli indici python:

# %%
lista = [22,33,44,55,66,77,88]
print(0, lista[0])
print(1, lista[1])
print(2, lista[2])
# Out:
# 0 22
# 1 33
# 2 44

# %%
lista.pop(0)
print(lista)
print(0, lista[0])
print(1, lista[1])
print(2, lista[2])
# Out:
# [33, 44, 55, 66, 77, 88]
# 0 33
# 1 44
# 2 55

# %% [markdown]
# In una lista gli indici forniscono la posizione. Non sono delle chiavi!
#
# Per Pandas è diverso:

# %%
import pandas as pd
tab = pd.read_csv('persone.csv', delimiter=',')
print(tab)
# Out:
#        nome    cognome  peso  altezza data_nascita sesso
# 0  Giacobbe  Trapanese  63.6     1.94   1971-12-26     M
# 1  Giovanni  Barillaro  84.0     1.80   1984-08-10     F
# 2   Bettina       Toso  93.5     1.88   1960-01-25     F
# 3     Carlo    Bettoni  80.5     1.79   1957-04-15     F
# 4     Mauro   Bompiani  96.4     1.64   1990-10-18     M
# 5   Gustavo    Galuppi  67.6     1.82   1966-07-09     M
# 6    Puccio    Tartini  54.9     1.59   1973-04-05     M
# 7      Tina  Gagliardi  83.1     1.84   1997-05-11     F
# 8      Pier    Udinesi  55.5     1.89   1993-05-15     M
# 9  Alderano     Turchi  82.8     1.94   1962-03-03     M

# %% [markdown]
# La prima colonna sono le "etichette di identificazione della riga" = una chiave unica associata alla riga e non la sua semplice posizione.
# Riordiniamo i dati e vediamo cosa accade:

# %%
tab2 = tab.sort_values(by="cognome")
print(tab2)
# Out:
#        nome    cognome  peso  altezza data_nascita sesso
# 1  Giovanni  Barillaro  84.0     1.80   1984-08-10     F
# 3     Carlo    Bettoni  80.5     1.79   1957-04-15     F
# 4     Mauro   Bompiani  96.4     1.64   1990-10-18     M
# 7      Tina  Gagliardi  83.1     1.84   1997-05-11     F
# 5   Gustavo    Galuppi  67.6     1.82   1966-07-09     M
# 6    Puccio    Tartini  54.9     1.59   1973-04-05     M
# 2   Bettina       Toso  93.5     1.88   1960-01-25     F
# 0  Giacobbe  Trapanese  63.6     1.94   1971-12-26     M
# 9  Alderano     Turchi  82.8     1.94   1962-03-03     M
# 8      Pier    Udinesi  55.5     1.89   1993-05-15     M

# %% [markdown]
# Per accedere ad un elemento con la sua chiave uso loc

# %%
print(tab2.loc[0])
# Out:
# nome              Giacobbe
# cognome          Trapanese
# peso                  63.6
# altezza               1.94
# data_nascita    1971-12-26
# sesso                    M
# Name: 0, dtype: object

# %% [markdown]
# Uso iloc per accedere alla posizione

# %%
print(tab2.iloc[0])
# Out:
# nome              Giovanni
# cognome          Barillaro
# peso                  84.0
# altezza                1.8
# data_nascita    1984-08-10
# sesso                    F
# Name: 1, dtype: object

# %% [markdown]
# index fornisce la chiave della riga alla posizione indicata. La riga alla posizione 2 ha come chiave:

# %%
idx = tab2.index[2]
print(idx)
# Out:
# 4

# %% [markdown]
# Lo slicing funziona con iloc.
#
# Per estrarre un gruppo di dati con posizione (o indice) compreso tra due valori scrivo:

# %%
tab3 = tab2.iloc[2:4]
print(tab3)
# Out:
#     nome    cognome  peso  altezza data_nascita sesso
# 4  Mauro   Bompiani  96.4     1.64   1990-10-18     M
# 7   Tina  Gagliardi  83.1     1.84   1997-05-11     F

# %%
tab4 = tab2.loc[range(0,4)]
print(tab4)
# Out:
#        nome    cognome  peso  altezza data_nascita sesso
# 0  Giacobbe  Trapanese  63.6     1.94   1971-12-26     M
# 1  Giovanni  Barillaro  84.0     1.80   1984-08-10     F
# 2   Bettina       Toso  93.5     1.88   1960-01-25     F
# 3     Carlo    Bettoni  80.5     1.79   1957-04-15     F

# %% [markdown]
# restringo la selezione specificando le colonne

# %%
tab4 = tab2.loc[range(0,4)][['cognome', 'data_nascita']]
print(tab4)
# Out:
#      cognome data_nascita
# 0  Trapanese   1971-12-26
# 1  Barillaro   1984-08-10
# 2       Toso   1960-01-25
# 3    Bettoni   1957-04-15

# %% [markdown]
# # head e tail

# %%
tab
# Out:
#        nome    cognome  peso  altezza data_nascita sesso
# 0  Giacobbe  Trapanese  63.6     1.94   1971-12-26     M
# 1  Giovanni  Barillaro  84.0     1.80   1984-08-10     F
# 2   Bettina       Toso  93.5     1.88   1960-01-25     F
# 3     Carlo    Bettoni  80.5     1.79   1957-04-15     F
# 4     Mauro   Bompiani  96.4     1.64   1990-10-18     M
# 5   Gustavo    Galuppi  67.6     1.82   1966-07-09     M
# 6    Puccio    Tartini  54.9     1.59   1973-04-05     M
# 7      Tina  Gagliardi  83.1     1.84   1997-05-11     F
# 8      Pier    Udinesi  55.5     1.89   1993-05-15     M
# 9  Alderano     Turchi  82.8     1.94   1962-03-03     M

# %%
tab.head(2)
# Out:
#        nome    cognome  peso  altezza data_nascita sesso
# 0  Giacobbe  Trapanese  63.6     1.94   1971-12-26     M
# 1  Giovanni  Barillaro  84.0     1.80   1984-08-10     F

# %%
tab.tail(3)
# Out:
#        nome    cognome  peso  altezza data_nascita sesso
# 7      Tina  Gagliardi  83.1     1.84   1997-05-11     F
# 8      Pier    Udinesi  55.5     1.89   1993-05-15     M
# 9  Alderano     Turchi  82.8     1.94   1962-03-03     M

# %% [markdown]
# # filtrare dati

# %%
tab
# Out:
#        nome    cognome  peso  altezza data_nascita sesso
# 0  Giacobbe  Trapanese  63.6     1.94   1971-12-26     M
# 1  Giovanni  Barillaro  84.0     1.80   1984-08-10     F
# 2   Bettina       Toso  93.5     1.88   1960-01-25     F
# 3     Carlo    Bettoni  80.5     1.79   1957-04-15     F
# 4     Mauro   Bompiani  96.4     1.64   1990-10-18     M
# 5   Gustavo    Galuppi  67.6     1.82   1966-07-09     M
# 6    Puccio    Tartini  54.9     1.59   1973-04-05     M
# 7      Tina  Gagliardi  83.1     1.84   1997-05-11     F
# 8      Pier    Udinesi  55.5     1.89   1993-05-15     M
# 9  Alderano     Turchi  82.8     1.94   1962-03-03     M

# %%
tab[tab.sesso == 'M']
# Out:
#        nome    cognome  peso  altezza data_nascita sesso
# 0  Giacobbe  Trapanese  63.6     1.94   1971-12-26     M
# 4     Mauro   Bompiani  96.4     1.64   1990-10-18     M
# 5   Gustavo    Galuppi  67.6     1.82   1966-07-09     M
# 6    Puccio    Tartini  54.9     1.59   1973-04-05     M
# 8      Pier    Udinesi  55.5     1.89   1993-05-15     M
# 9  Alderano     Turchi  82.8     1.94   1962-03-03     M

# %%
tab[tab["sesso"] == 'F']
# Out:
#        nome    cognome  peso  altezza data_nascita sesso
# 1  Giovanni  Barillaro  84.0     1.80   1984-08-10     F
# 2   Bettina       Toso  93.5     1.88   1960-01-25     F
# 3     Carlo    Bettoni  80.5     1.79   1957-04-15     F
# 7      Tina  Gagliardi  83.1     1.84   1997-05-11     F

# %%
tab[tab.altezza > 1.80]
# Out:
#        nome    cognome  peso  altezza data_nascita sesso
# 0  Giacobbe  Trapanese  63.6     1.94   1971-12-26     M
# 2   Bettina       Toso  93.5     1.88   1960-01-25     F
# 5   Gustavo    Galuppi  67.6     1.82   1966-07-09     M
# 7      Tina  Gagliardi  83.1     1.84   1997-05-11     F
# 8      Pier    Udinesi  55.5     1.89   1993-05-15     M
# 9  Alderano     Turchi  82.8     1.94   1962-03-03     M

# %% [markdown]
# AND &
#
# OR |
#
# NOT ~

# %%
tab[(tab.altezza > 1.80) & (tab.sesso == 'F')]
# Out:
#       nome    cognome  peso  altezza data_nascita sesso
# 2  Bettina       Toso  93.5     1.88   1960-01-25     F
# 7     Tina  Gagliardi  83.1     1.84   1997-05-11     F

# %%
tab[(tab.altezza > 1.80) | (tab.peso <= 60.0)]
# Out:
#        nome    cognome  peso  altezza data_nascita sesso
# 0  Giacobbe  Trapanese  63.6     1.94   1971-12-26     M
# 2   Bettina       Toso  93.5     1.88   1960-01-25     F
# 5   Gustavo    Galuppi  67.6     1.82   1966-07-09     M
# 6    Puccio    Tartini  54.9     1.59   1973-04-05     M
# 7      Tina  Gagliardi  83.1     1.84   1997-05-11     F
# 8      Pier    Udinesi  55.5     1.89   1993-05-15     M
# 9  Alderano     Turchi  82.8     1.94   1962-03-03     M

# %%
tab[ ~(tab.nome == 'Tina') ]
# Out:
#        nome    cognome  peso  altezza data_nascita sesso
# 0  Giacobbe  Trapanese  63.6     1.94   1971-12-26     M
# 1  Giovanni  Barillaro  84.0     1.80   1984-08-10     F
# 2   Bettina       Toso  93.5     1.88   1960-01-25     F
# 3     Carlo    Bettoni  80.5     1.79   1957-04-15     F
# 4     Mauro   Bompiani  96.4     1.64   1990-10-18     M
# 5   Gustavo    Galuppi  67.6     1.82   1966-07-09     M
# 6    Puccio    Tartini  54.9     1.59   1973-04-05     M
# 8      Pier    Udinesi  55.5     1.89   1993-05-15     M
# 9  Alderano     Turchi  82.8     1.94   1962-03-03     M

# %% [markdown]
# ordinamenti

# %%
tab2
# Out:
#        nome    cognome  peso  altezza data_nascita sesso
# 1  Giovanni  Barillaro  84.0     1.80   1984-08-10     F
# 3     Carlo    Bettoni  80.5     1.79   1957-04-15     F
# 4     Mauro   Bompiani  96.4     1.64   1990-10-18     M
# 7      Tina  Gagliardi  83.1     1.84   1997-05-11     F
# 5   Gustavo    Galuppi  67.6     1.82   1966-07-09     M
# 6    Puccio    Tartini  54.9     1.59   1973-04-05     M
# 2   Bettina       Toso  93.5     1.88   1960-01-25     F
# 0  Giacobbe  Trapanese  63.6     1.94   1971-12-26     M
# 9  Alderano     Turchi  82.8     1.94   1962-03-03     M
# 8      Pier    Udinesi  55.5     1.89   1993-05-15     M

# %%
tab2.sort_index(ascending=False)
# Out:
#        nome    cognome  peso  altezza data_nascita sesso
# 9  Alderano     Turchi  82.8     1.94   1962-03-03     M
# 8      Pier    Udinesi  55.5     1.89   1993-05-15     M
# 7      Tina  Gagliardi  83.1     1.84   1997-05-11     F
# 6    Puccio    Tartini  54.9     1.59   1973-04-05     M
# 5   Gustavo    Galuppi  67.6     1.82   1966-07-09     M
# 4     Mauro   Bompiani  96.4     1.64   1990-10-18     M
# 3     Carlo    Bettoni  80.5     1.79   1957-04-15     F
# 2   Bettina       Toso  93.5     1.88   1960-01-25     F
# 1  Giovanni  Barillaro  84.0     1.80   1984-08-10     F
# 0  Giacobbe  Trapanese  63.6     1.94   1971-12-26     M

# %%
tab.sort_values(by="nome", ascending=True)
# Out:
#        nome    cognome  peso  altezza data_nascita sesso
# 9  Alderano     Turchi  82.8     1.94   1962-03-03     M
# 2   Bettina       Toso  93.5     1.88   1960-01-25     F
# 3     Carlo    Bettoni  80.5     1.79   1957-04-15     F
# 0  Giacobbe  Trapanese  63.6     1.94   1971-12-26     M
# 1  Giovanni  Barillaro  84.0     1.80   1984-08-10     F
# 5   Gustavo    Galuppi  67.6     1.82   1966-07-09     M
# 4     Mauro   Bompiani  96.4     1.64   1990-10-18     M
# 8      Pier    Udinesi  55.5     1.89   1993-05-15     M
# 6    Puccio    Tartini  54.9     1.59   1973-04-05     M
# 7      Tina  Gagliardi  83.1     1.84   1997-05-11     F
